# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as dt

# %%
customer = pd.read_csv(r'c:\\Users\\Dell\\Documents\\Python Programing Alab\\Python Foundation Case Study 1 - Retail Case Study\\Customer.csv')
customer
# Out:
#       customer_Id         DOB Gender  city_code
# 0          268408  02-01-1970      M        4.0
# 1          269696  07-01-1970      F        8.0
# 2          268159  08-01-1970      F        8.0
# 3          270181  10-01-1970      F        2.0
# 4          268073  11-01-1970      M        1.0
# ...           ...         ...    ...        ...
# 5642       274474  19-12-1992      M        2.0
# 5643       267666  24-12-1992      M        6.0
# 5644       270476  25-12-1992      F        3.0
# 5645       269626  27-12-1992      F        5.0
# 5646       274308  29-12-1992      F        5.0
#
# [5647 rows x 4 columns]

# %%
transaction = pd.read_csv(r'C:\Users\Dell\Documents\Python Programing Alab\Python Foundation Case Study 1 - Retail Case Study\Transactions.csv')
transaction
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
#        Qty  Rate      Tax  total_amt Store_type
# ...

# %%
product = pd.read_csv(r'C:\Users\Dell\Documents\Python Programing Alab\Python Foundation Case Study 1 - Retail Case Study\prod_cat_info.csv')
product
# Out:
#     prod_cat_code          prod_cat  prod_sub_cat_code          prod_subcat
# 0               1          Clothing                  4                 Mens
# 1               1          Clothing                  1                Women
# 2               1          Clothing                  3                 Kids
# 3               2          Footwear                  1                 Mens
# 4               2          Footwear                  3                Women
# 5               2          Footwear                  4                 Kids
# 6               3       Electronics                  4              Mobiles
# 7               3       Electronics                  5            Computers
# 8               3       Electronics                  8  Personal Appliances
# 9               3       Electronics                  9              Cameras
# 10              3       Electronics                 10      Audio and video
# ...

# %%
product.rename(columns={"prod_sub_cat_code":"prod_subcat_code"},inplace=True)
product
# Out:
#     prod_cat_code          prod_cat  prod_subcat_code          prod_subcat
# 0               1          Clothing                 4                 Mens
# 1               1          Clothing                 1                Women
# 2               1          Clothing                 3                 Kids
# 3               2          Footwear                 1                 Mens
# 4               2          Footwear                 3                Women
# 5               2          Footwear                 4                 Kids
# 6               3       Electronics                 4              Mobiles
# 7               3       Electronics                 5            Computers
# 8               3       Electronics                 8  Personal Appliances
# 9               3       Electronics                 9              Cameras
# 10              3       Electronics                10      Audio and video
# ...

# %%
m_data= pd.merge(left=transaction, right=product, on=["prod_cat_code","prod_subcat_code"],how="left")
m_data
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
# ...

# %%
Customer_Final = pd.merge(left=m_data, right=customer,right_on="customer_Id", left_on="cust_id", how="left")
Customer_Final
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
# ...

# %%
Customer_Final.dtypes
# Out:
# transaction_id        int64
# cust_id               int64
# tran_date            object
# prod_subcat_code      int64
# prod_cat_code         int64
# Qty                   int64
# Rate                  int64
# Tax                 float64
# total_amt           float64
# Store_type           object
# prod_cat             object
# prod_subcat          object
# customer_Id           int64
# DOB                  object
# Gender               object
# city_code           float64
# dtype: object

# %%
#changing it to correct datatypes for "DOB" and "tran_date" 

Customer_Final["DOB"] = pd.to_datetime(Customer_Final["DOB"], format="%d-%m-%Y")
Customer_Final["DOB"].head()
# Out:
# 0   1981-09-26
# 1   1973-05-11
# 2   1992-07-27
# 3   1981-06-08
# 4   1992-07-27
# Name: DOB, dtype: datetime64[ns]

# %%
Customer_Final["tran_date"] = pd.to_datetime(Customer_Final["tran_date"])
Customer_Final["tran_date"].head()
# Out:
# 0   2014-02-28
# 1   2014-02-27
# 2   2014-02-24
# 3   2014-02-24
# 4   2014-02-23
# Name: tran_date, dtype: datetime64[ns]

# %% [markdown]
# #checking duplicates and droping it from dataframe

# %%
Customer_Final.duplicated().sum()
# Out:
# 13

# %%
Customer_Final.drop_duplicates(inplace=True)

# %%
Customer_Final.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Q.2(A)-Columns Names and Data Types

# %%
Customer_Final.columns
# Out:
# Index(['transaction_id', 'cust_id', 'tran_date', 'prod_subcat_code',
#        'prod_cat_code', 'Qty', 'Rate', 'Tax', 'total_amt', 'Store_type',
#        'prod_cat', 'prod_subcat', 'customer_Id', 'DOB', 'Gender', 'city_code'],
#       dtype='object')

# %%
Customer_Final.dtypes
# Out:
# transaction_id               int64
# cust_id                      int64
# tran_date           datetime64[ns]
# prod_subcat_code             int64
# prod_cat_code                int64
# Qty                          int64
# Rate                         int64
# Tax                        float64
# total_amt                  float64
# Store_type                  object
# prod_cat                    object
# prod_subcat                 object
# customer_Id                  int64
# DOB                 datetime64[ns]
# Gender                      object
# city_code                  float64
# dtype: object

# %% [markdown]
# # Q.2(B)-Top/Bottom 10 observation

# %%
#(2)
Customer_Final.head(10)
# Out:
#    transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351 2014-02-28                 1              1   -5
# 1     29258453508   270384 2014-02-27                 5              3   -5
# 2     51750724947   273420 2014-02-24                 6              5   -2
# 3     93274880719   271509 2014-02-24                11              6   -3
# 4     51750724947   273420 2014-02-23                 6              5   -2
# 5     97439039119   272357 2014-02-23                 8              3   -2
# 6     45649838090   273667 2014-02-22                11              6   -1
# 7     22643667930   271489 2014-02-22                12              6   -1
# 8     79792372943   275108 2014-02-22                 3              1   -3
# 9     50076728598   269014 2014-02-21                 8              3   -4
#
#    Rate      Tax  total_amt Store_type          prod_cat          prod_subcat  \
# ...

# %%
#(3)
Customer_Final.tail(10)
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 23043     49882891062   271982 2011-01-25                10              5
# 23044     14787475597   273982 2011-01-25                 4              3
# 23045     50691119572   273031 2011-01-25                 6              5
# 23046     40893803228   272049 2011-01-25                11              6
# 23047     30856003613   266866 2011-01-25                 4              2
# 23048     94340757522   274550 2011-01-25                12              5
# 23049     89780862956   270022 2011-01-25                 4              1
# 23050     85115299378   271020 2011-01-25                 2              6
# 23051     72870271171   270911 2011-01-25                11              5
# 23052     77960931771   271961 2011-01-25                11              5
#
#        Qty  Rate      Tax  total_amt Store_type          prod_cat  \
# 23043    4  1330  558.600   5878.600     e-Shop             Books
# ...

# %% [markdown]
# # Q.2(C)“Five-number summary” for continuous variables (min, Q1, median, Q3 and max)

# %%
#min
Customer_Final.min()
# Out:
# transaction_id                  3268991
# cust_id                          266783
# tran_date           2011-01-02 00:00:00
# prod_subcat_code                      1
# prod_cat_code                         1
# Qty                                  -5
# Rate                              -1499
# Tax                                7.35
# total_amt                     -8270.925
# Store_type               Flagship store
# prod_cat                           Bags
# prod_subcat                    Academic
# customer_Id                      266783
# DOB                 1970-01-02 00:00:00
# city_code                           1.0
# dtype: object

# %%
#Q1
Customer_Final.quantile(.25)
# Out:
# transaction_id      2.493315e+10
# cust_id             2.689350e+05
# prod_subcat_code    3.000000e+00
# prod_cat_code       2.000000e+00
# Qty                 1.000000e+00
# Rate                3.120000e+02
# Tax                 9.828000e+01
# total_amt           7.624500e+02
# customer_Id         2.689350e+05
# city_code           3.000000e+00
# Name: 0.25, dtype: float64

# %%
# median
Customer_Final.median()
# Out:
# transaction_id      5.009188e+10
# cust_id             2.709805e+05
# prod_subcat_code    5.000000e+00
# prod_cat_code       4.000000e+00
# Qty                 3.000000e+00
# Rate                7.100000e+02
# Tax                 1.990800e+02
# total_amt           1.756950e+03
# customer_Id         2.709805e+05
# city_code           5.000000e+00
# dtype: float64

# %%
#Q3
Customer_Final.quantile(.75)
# Out:
# transaction_id      7.532632e+10
# cust_id             2.731142e+05
# prod_subcat_code    1.000000e+01
# prod_cat_code       5.000000e+00
# Qty                 4.000000e+00
# Rate                1.109000e+03
# Tax                 3.657675e+02
# total_amt           3.570255e+03
# customer_Id         2.731142e+05
# city_code           8.000000e+00
# Name: 0.75, dtype: float64

# %%
# max
Customer_Final.max()
# Out:
# transaction_id              99987549630
# cust_id                          275265
# tran_date           2014-12-02 00:00:00
# prod_subcat_code                     12
# prod_cat_code                         6
# Qty                                   5
# Rate                               1500
# Tax                               787.5
# total_amt                        8287.5
# Store_type                       e-Shop
# prod_cat               Home and kitchen
# prod_subcat                       Women
# customer_Id                      275265
# DOB                 1992-12-29 00:00:00
# city_code                          10.0
# dtype: object

# %% [markdown]
# # Q.2(D)-Frequency tables for all the categorical variables

# %%
Customer_Final.loc[:,Customer_Final.dtypes == 'object'].describe()
# Out:
#        Store_type prod_cat prod_subcat Gender
# count       23040    23040       23040  23031
# unique          4        6          18      2
# top        e-Shop    Books       Women      M
# freq         9304     6066        3046  11804

# %% [markdown]
# # Q(3). Generate histograms for all continuous variables and frequency bars for categorical variables.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

continuous_customers = Customer_Final.loc[:,['prod_subcat_code','prod_cat_code','Qty','Rate','Tax','total_amt',]]

for var in continuous_customers.columns:
    continuous_customers[var].plot(kind='hist')
    plt.title(var)
    plt.show()

# %% [markdown]
# # frequency bars for categorical variables.

# %%
import seaborn as sns

# %%
categorical_customer = Customer_Final.loc[:,Customer_Final.dtypes == 'object']
sns.countplot(categorical_customer['Gender'])
plt.figure(figsize=(8,8))

import warnings
warnings.filterwarnings("ignore")

# %%
sns.countplot(categorical_customer['Store_type'])
plt.figure(figsize=(8,8))
plt.show()

import warnings
warnings.filterwarnings("ignore")

# %%
plt.figure(figsize=(6,8))
categorical_customer.groupby('prod_subcat')['prod_subcat'].count().plot(kind= 'barh')
plt.xlabel('count')
plt.ylabel('product subcategory')
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(categorical_customer['prod_cat'])
plt.xlabel('Product Category')
plt.ylabel('Frequency')
plt.show()

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Q.(4) a. Time period of the available transaction data

# %%
Customer_Final.sort_values(by="tran_date")
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 22899     36332303449   268624 2011-01-02                10              6
# 22893     25374972356   268904 2011-01-02                 2              6
# 22894     15662366857   272756 2011-01-02                 5              3
# 22895     28972634039   275227 2011-01-02                 9              3
# 22896     60041644943   267309 2011-01-02                 3              2
# ...               ...      ...        ...               ...            ...
# 161       65228973233   270009 2014-12-02                11              5
# 162       83661978186   274678 2014-12-02                10              3
# 147       36792372906   275246 2014-12-02                 2              6
# 154       74023090711   271180 2014-12-02                 8              3
# 146       17146707816   274897 2014-12-02                12              5
#
# ...

# %%
min_date = Customer_Final["tran_date"].min()
min_date
# Out:
# Timestamp('2011-01-02 00:00:00')

# %%
max_date = Customer_Final["tran_date"].max()
max_date
# Out:
# Timestamp('2014-12-02 00:00:00')

# %%
print("Time period of the available transaction data is from ",pd.to_datetime(min_date,format="%d/%m/%Y"),'to', pd.to_datetime(max_date,format="%d/%m/%Y"))
# Out:
# Time period of the available transaction data is from  2011-01-02 00:00:00 to 2014-12-02 00:00:00

# %% [markdown]
# # Q4-(b.) Count of transactions where the total amount of transaction was negative

# %%
negative_transaction = Customer_Final.loc[Customer_Final['total_amt']<0,'transaction_id'].count()

print("The total amount of negative transaction is: ",negative_transaction)
# Out:
# The total amount of negative transaction is:  2164

# %% [markdown]
# # (Q5.) Analyze which product categories are more popular among females vs male customers.

# %%
product_gender =Customer_Final[['Gender','prod_cat','Qty']].groupby(['prod_cat','Gender']).sum().reset_index()
product_gender
# Out:
#             prod_cat Gender   Qty
# 0               Bags      F  2364
# 1               Bags      M  2346
# 2              Books      F  7080
# 3              Books      M  7587
# 4           Clothing      F  3425
# 5           Clothing      M  3748
# 6        Electronics      F  5832
# 7        Electronics      M  6486
# 8           Footwear      F  3721
# 9           Footwear      M  3561
# 10  Home and kitchen      F  4898
# 11  Home and kitchen      M  5051

# %%
product_gender.pivot(index="Gender",columns="prod_cat",values="Qty")
# Out:
# prod_cat  Bags  Books  Clothing  Electronics  Footwear  Home and kitchen
# Gender
# F         2364   7080      3425         5832      3721              4898
# M         2346   7587      3748         6486      3561              5051

# %% [markdown]
# # (Q6). Which City code has the maximum customers and what was the percentage of customers from that city?

# %%
maximum_customer =  Customer_Final.groupby('city_code')['customer_Id'].count().sort_values(ascending =False)
maximum_customer
# Out:
# city_code
# 4.0     2422
# 3.0     2410
# 5.0     2357
# 7.0     2356
# 10.0    2333
# 8.0     2328
# 2.0     2268
# 1.0     2255
# 9.0     2176
# 6.0     2127
# Name: customer_Id, dtype: int64

# %%
percentage = round((maximum_customer[4.0] / maximum_customer.sum()) * 100,2)
percentage
# Out:
# 10.52

# %% [markdown]
# # (Q7). Which store type sells the maximum products by value and by quantity?

# %%
prod_value_quantity =Customer_Final.groupby("Store_type")["Rate","Qty"].sum().sort_values(by =["Qty","Rate"],ascending=False).reset_index()
prod_value_quantity
# Out:
#        Store_type     Rate    Qty
# 0          e-Shop  5945770  22790
# 1             MBR  2953665  11195
# 2  Flagship store  2942874  11142
# 3        TeleShop  2836359  10993

# %%
prod_value_quantity.loc[0]
# Out:
# Store_type     e-Shop
# Rate          5945770
# Qty             22790
# Name: 0, dtype: object

# %% [markdown]
# # (Q8). What was the total amount earned from the "Electronics" and "Clothing" categories from Flagship Stores?

# %%
temp = Customer_Final.groupby(by = ["Store_type","prod_cat"])

Prod_categorie = temp[["total_amt"]].sum().reset_index()
Prod_categorie
# Out:
#         Store_type          prod_cat    total_amt
# 0   Flagship store              Bags   870548.835
# 1   Flagship store             Books  2493677.810
# 2   Flagship store          Clothing  1194423.230
# 3   Flagship store       Electronics  2215136.040
# 4   Flagship store          Footwear  1234806.560
# 5   Flagship store  Home and kitchen  1713004.150
# 6              MBR              Bags   848678.675
# 7              MBR             Books  2496039.195
# 8              MBR          Clothing  1287686.335
# 9              MBR       Electronics  2107969.825
# 10             MBR          Footwear  1112163.715
# 11             MBR  Home and kitchen  1822403.570
# 12        TeleShop              Bags   789181.055
# 13        TeleShop             Books  2545714.470
# 14        TeleShop          Clothing  1241834.360
# 15        TeleShop       Electronics  1978457.195
# 16        TeleShop          Footwear  1235719.290
# 17        TeleShop  Home and kitchen  1581227.375
# ...

# %%
Prod_categorie.pivot(index="prod_cat",columns="Store_type", values="total_amt")
# Out:
# Store_type        Flagship store          MBR     TeleShop       e-Shop
# prod_cat
# Bags                  870548.835   848678.675   789181.055  1617933.265
# Books                2493677.810  2496039.195  2545714.470  5297161.155
# Clothing             1194423.230  1287686.335  1241834.360  2527193.565
# Electronics          2215136.040  2107969.825  1978457.195  4429142.770
# Footwear             1234806.560  1112163.715  1235719.290  2643215.250
# Home and kitchen     1713004.150  1822403.570  1581227.375  3327977.120

# %%
Prod_categorie.loc[2:3].sum()
# Out:
# Store_type    Flagship storeFlagship store
# prod_cat               ClothingElectronics
# total_amt                       3409559.27
# dtype: object

# %% [markdown]
# # (Q9). What was the total amount earned from "Male" customers under the "Electronics" category?

# %%
gender_group = Customer_Final.pivot_table(index="prod_cat",columns="Gender",values="total_amt",aggfunc="sum")
gender_group
# Out:
# Gender                      F            M
# prod_cat
# Bags              2079618.840  2046722.990
# Books             6174590.825  6645972.775
# Clothing          3026750.805  3224079.495
# Electronics       5019354.210  5711351.620
# Footwear          3203155.215  3020200.365
# Home and kitchen  4133702.235  4305169.505

# %%
male_earning = gender_group.loc["Electronics","M"]
male_earning
# Out:
# 5711351.62000002

# %%
print("The total amount earned from Male customers under the Electronics category is: ",male_earning)
# Out:
# The total amount earned from Male customers under the Electronics category is:  5711351.62000002

# %% [markdown]
# # (Q10). How many customers have more than 10 unique transactions, after removing all transactions which have any negative amounts?

# %%
## removing all transactions which have any negative amounts

positive_trans = Customer_Final.loc[Customer_Final["total_amt"]>0,:]
positive_trans
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 10        29258453508   270384 2014-02-20                 5              3
# 11        25455265351   267750 2014-02-20                12              6
# 12         1571002198   275023 2014-02-20                 6              5
# 14        36554696014   269345 2014-02-20                 3              5
# 15        56814940239   268799 2014-02-20                 7              5
# ...               ...      ...        ...               ...            ...
# 23048     94340757522   274550 2011-01-25                12              5
# 23049     89780862956   270022 2011-01-25                 4              1
# 23050     85115299378   271020 2011-01-25                 2              6
# 23051     72870271171   270911 2011-01-25                11              5
# 23052     77960931771   271961 2011-01-25                11              5
#
# ...

# %%
unique_trans= positive_trans.groupby(["customer_Id","prod_subcat","prod_cat"])['transaction_id'].count().reset_index()

unique_trans
# Out:
#        customer_Id  prod_subcat          prod_cat  transaction_id
# 0           266783         Mens          Clothing               2
# 1           266783         Mens          Footwear               1
# 2           266783  Non-Fiction             Books               1
# 3           266784      Fiction             Books               1
# 4           266784      Mobiles       Electronics               1
# ...            ...          ...               ...             ...
# 19273       275264  Non-Fiction             Books               1
# 19274       275264        Tools  Home and kitchen               1
# 19275       275265     Academic             Books               1
# 19276       275265   Furnishing  Home and kitchen               1
# 19277       275265         Mens              Bags               1
#
# [19278 rows x 4 columns]

# %%
count_unique_trans = unique_trans.groupby('customer_Id')['transaction_id'].count().sort_values(ascending=False).reset_index()

count_unique_trans
# Out:
#       customer_Id  transaction_id
# 0          270908              10
# 1          272286              10
# 2          274854              10
# 3          273014              10
# 4          268076               9
# ...           ...             ...
# 5501       270259               1
# 5502       270265               1
# 5503       267996               1
# 5504       272656               1
# 5505       269114               1
#
# [5506 rows x 2 columns]

# %%
count_unique_trans[count_unique_trans['transaction_id'] > 10]
# Out:
# Empty DataFrame
# Columns: [customer_Id, transaction_id]
# Index: []

# %%
print('There are no unique transactions which is greater than 10')
# Out:
# There are no unique transactions which is greater than 10

# %% [markdown]
# # (Q11). For all customers aged between 25 - 35, find out:
#   # (A). What was the total amount spent for “Electronics” and “Books” product categories?

# %%
## adding new column "Age"

now = pd.Timestamp('now')
Customer_Final['DOB'] = pd.to_datetime(Customer_Final['DOB'], format="%m%d%y")    # 1
Customer_Final['DOB'] = Customer_Final['DOB'].where(Customer_Final['DOB'] < now, Customer_Final['DOB'] -  np.timedelta64(100, 'Y'))   # 2
Customer_Final['AGE'] = (now - Customer_Final['DOB']).astype('<m8[Y]')

# %%
Customer_Final['Age_cat'] = pd.cut(Customer_Final['AGE'],bins=[24,35,46,57],labels=['25-35','36-46','47-57'],include_lowest=True)

Customer_Final
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351 2014-02-28                 1              1
# 1         29258453508   270384 2014-02-27                 5              3
# 2         51750724947   273420 2014-02-24                 6              5
# 3         93274880719   271509 2014-02-24                11              6
# 4         51750724947   273420 2014-02-23                 6              5
# ...               ...      ...        ...               ...            ...
# 23048     94340757522   274550 2011-01-25                12              5
# 23049     89780862956   270022 2011-01-25                 4              1
# 23050     85115299378   271020 2011-01-25                 2              6
# 23051     72870271171   270911 2011-01-25                11              5
# 23052     77960931771   271961 2011-01-25                11              5
#
# ...

# %%
# grouping the dataframe 'customer_final' on the basis of 'Age_cat' and 'prod_cat'

customer_25_35 = Customer_Final.groupby(['Age_cat','prod_cat'])['total_amt'].sum()

customer_25_35
# Out:
# Age_cat  prod_cat
# 25-35    Bags                1177956.520
#          Books               3584524.970
#          Clothing            2054050.245
#          Electronics         3268328.115
#          Footwear            1932488.090
#          Home and kitchen    2556455.070
# 36-46    Bags                1937121.355
#          Books               6373646.630
#          Clothing            2913813.175
#          Electronics         4997601.180
#          Footwear            2913687.205
#          Home and kitchen    4097001.870
# 47-57    Bags                1011263.955
#          Books               2874421.030
#          Clothing            1283274.070
#          Electronics         2464776.535
#          Footwear            1379729.520
#          Home and kitchen    1791155.275
# Name: total_amt, dtype: float64

# %%
## Total amount spent for “Electronics” and “Books” product categories

customer_25_35.loc['25-35',['Books','Electronics']].sum()
# Out:
# 6852853.085000003

# %% [markdown]
# # (b). What was the total amount spent by these customers between 1st Jan, 2014 to 1st Mar, 2014?

# %%
customer_age_25_35 = Customer_Final[Customer_Final['Age_cat']=='25-35']

customer_age_25_35
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 2         51750724947   273420 2014-02-24                 6              5
# 4         51750724947   273420 2014-02-23                 6              5
# 11        25455265351   267750 2014-02-20                12              6
# 23        91116291703   268509 2014-02-20                 1              2
# 28        88853694830   268444 2014-02-20                 4              4
# ...               ...      ...        ...               ...            ...
# 23033     32887353269   268885 2011-01-25                 3              1
# 23034     28972634039   275227 2011-01-25                 9              3
# 23035     42161597232   267094 2011-01-25                 3              1
# 23038     61812307223   274306 2011-01-25                 4              4
# 23044     14787475597   273982 2011-01-25                 4              3
#
# ...

# %%
# getting all the data with transaction date between 1st Jan 2014 to 1st Mar 2014?

trans_date = customer_age_25_35[(customer_age_25_35['tran_date'] >= '2014-01-01') & (customer_age_25_35['tran_date'] <= '2014-03-01')]

trans_date
# Out:
#       transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 2        51750724947   273420 2014-02-24                 6              5
# 4        51750724947   273420 2014-02-23                 6              5
# 11       25455265351   267750 2014-02-20                12              6
# 23       91116291703   268509 2014-02-20                 1              2
# 28       88853694830   268444 2014-02-20                 4              4
# ...              ...      ...        ...               ...            ...
# 1048     14460826915   269348 2014-01-01                11              6
# 1051     32889219128   269536 2014-01-01                10              5
# 1054     42711619809   271701 2014-01-01                 1              2
# 1059     67088172893   271877 2014-01-01                 1              1
# 1061     63635040022   268886 2014-01-01                 3              2
#
#       Qty  Rate      Tax  total_amt Store_type          prod_cat  prod_subcat  \
# ...

# %%
print('The total amount spent by customers aged 25-35 between 1st Jan 2014 to 1st Mar 2014 is',trans_date['total_amt'].sum())
# Out:
# The total amount spent by customers aged 25-35 between 1st Jan 2014 to 1st Mar 2014 is 471356.53500000003
